# %% [markdown]
# ## PROJECT

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### *This code is used to load data from a CSV (Comma-Separated Values) file into Pandas DataFrame in Python

# %%
df=pd.read_csv(r"C:\Users\user\Desktop\PYTHON\lives-saved-vaccines new.csv")

# %%
df
# Out:
#                   Entity  Year  Diphtheria  Hepatitis B   Measles    Polio  \
# 0                 Africa  2024      210000       129000  28660000   151000
# 1               Americas  2024        7000        18000  14894000   218000
# 2  Eastern Mediterranean  2024       30000        27000  12887000   119000
# 3                 Europe  2024        3000        24000   6562000   244000
# 4        South-east Asia  2024       84000        73000  20517000   347000
# 5        Western Pacific  2024       23000       203000  10192000   491000
# 6                  World  2024      357000       464000  93712000  1570000
#
#    Rubella   Tetanus  Tuberculosis  Yellow fever  Whooping cough (Pertussis)  \
# 0    45000   9544000       6568000        549000                     4197000
# 1    30000     65000        231000          8000                      367000
# 2    34000   8501000        822000          1000                     1861000
# ...

# %%
df.head()
# Out:
#                   Entity  Year  Diphtheria  Hepatitis B   Measles   Polio  \
# 0                 Africa  2024      210000       129000  28660000  151000
# 1               Americas  2024        7000        18000  14894000  218000
# 2  Eastern Mediterranean  2024       30000        27000  12887000  119000
# 3                 Europe  2024        3000        24000   6562000  244000
# 4        South-east Asia  2024       84000        73000  20517000  347000
#
#    Rubella  Tetanus  Tuberculosis  Yellow fever  Whooping cough (Pertussis)  \
# 0    45000  9544000       6568000        549000                     4197000
# 1    30000    65000        231000          8000                      367000
# 2    34000  8501000        822000          1000                     1861000
# 3    14000    21000        108000             0                      231000
# 4   112000  9218000       2416000             0                     4437000
#
# ...

# %%
print(df.isnull().sum())
# Out:
# Entity                           0
# Year                             0
# Diphtheria                       0
# Hepatitis B                      0
# Measles                          0
# Polio                            0
# Rubella                          0
# Tetanus                          0
# Tuberculosis                     0
# Yellow fever                     0
# Whooping cough (Pertussis)       0
# Total                            0
# Streptococcus pneumoniae         0
# Rotavirus                        0
# Neisseria meningitidis A         0
# Japanese encephalitis            0
# Haemophilus influenzae type B    0
# dtype: int64

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Entity                         7 non-null      object
#  1   Year                           7 non-null      int64
#  2   Diphtheria                     7 non-null      int64
#  3   Hepatitis B                    7 non-null      int64
#  4   Measles                        7 non-null      int64
#  5   Polio                          7 non-null      int64
#  6   Rubella                        7 non-null      int64
#  7   Tetanus                        7 non-null      int64
#  8   Tuberculosis                   7 non-null      int64
#  9   Yellow fever                   7 non-null      int64
#  10  Whooping cough (Pertussis)     7 non-null      int64
#  11  Total                          7 non-null      int64
# ...

# %%
df.shape
# Out:
# (7, 17)

# %%
df = df.fillna(0)

# %%
df
# Out:
#                   Entity  Year  Diphtheria  Hepatitis B   Measles    Polio  \
# 0                 Africa  2024      210000       129000  28660000   151000
# 1               Americas  2024        7000        18000  14894000   218000
# 2  Eastern Mediterranean  2024       30000        27000  12887000   119000
# 3                 Europe  2024        3000        24000   6562000   244000
# 4        South-east Asia  2024       84000        73000  20517000   347000
# 5        Western Pacific  2024       23000       203000  10192000   491000
# 6                  World  2024      357000       464000  93712000  1570000
#
#    Rubella   Tetanus  Tuberculosis  Yellow fever  Whooping cough (Pertussis)  \
# 0    45000   9544000       6568000        549000                     4197000
# 1    30000     65000        231000          8000                      367000
# 2    34000   8501000        822000          1000                     1861000
# ...

# %% [markdown]
# ## Immunization Trends Over Time: How have immunization rates for different diseases changed over the years?
